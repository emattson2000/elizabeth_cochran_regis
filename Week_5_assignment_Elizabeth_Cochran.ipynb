# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %%
import pandas as pd

df = pd.read_csv('prepped_churn_data2.csv', index_col='customerID', )
print(df)
# Out:
#             tenure  PhoneService  Contract              PaymentMethod  \
# customerID
# 7590-VHVEG       1             0         0           Electronic check
# 5575-GNVDE      34             1         1               Mailed check
# 3668-QPYBK       2             1         0               Mailed check
# 7795-CFOCW      45             0         1  Bank transfer (automatic)
# 9237-HQITU       2             1         0           Electronic check
# ...            ...           ...       ...                        ...
# 6840-RESVB      24             1         1               Mailed check
# 2234-XADUH      72             1         1    Credit card (automatic)
# 4801-JZAZL      11             0         0           Electronic check
# 8361-LTMKD       4             1         0               Mailed check
# 3186-AJIEK      66             1         2  Bank transfer (automatic)
#
#             MonthlyCharges  TotalCharges  Churn  total_tenure_ratio
# customerID
# 7590-VHVEG           29.85         29.85      0           29.850000
# 5575-GNVDE           56.95       1889.50      0           55.573529
# 3668-QPYBK           53.85        108.15      1           54.075000
# 7795-CFOCW           42.30       1840.75      0           40.905556
# 9237-HQITU           70.70        151.65      1           75.825000
# ...                    ...           ...    ...                 ...
# 6840-RESVB           84.80       1990.50      0           82.937500
# 2234-XADUH          103.20       7362.90      0          102.262500
# 4801-JZAZL           29.60        346.45      0           31.495455
# 8361-LTMKD           74.40        306.60      1           76.650000
# 3186-AJIEK          105.65       6844.50      0          103.704545
#
# [7032 rows x 8 columns]

# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (3.3.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: ipython>=5.5.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (8.27.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (8.1.2)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (4.66.5)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (3.1.4)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (0.12.3)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (4.5.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (0.60.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (2.1.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (8.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (5.9.2)
# Requirement already satisfied: cloudpickle in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (0.14.3)
# Requirement already satisfied: sktime==0.26.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from sktime==0.26.0->pycaret) (24.1)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.20.2)
# Requirement already satisfied: decorator in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipython>=5.5.0->pycaret) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: exceptiongroup in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipython>=5.5.0->pycaret) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipython>=5.5.0->pycaret) (4.11.0)
# Requirement already satisfied: colorama in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from matplotlib<3.8.0->pycaret) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.19.2)
# Requirement already satisfied: jupyter-core in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from numba>=0.55.0->pycaret) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pandas<2.2.0->pycaret) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pandas<2.2.0->pycaret) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from plotly>=5.14.0->pycaret) (9.0.0)
# Requirement already satisfied: dash>=2.9.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.18.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.7)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.11)
# Requirement already satisfied: urllib3 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.2.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from pmdarima>=2.0.4->pycaret) (75.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from requests>=2.27.1->pycaret) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from requests>=2.27.1->pycaret) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from requests>=2.27.1->pycaret) (2024.8.30)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.4)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: retrying in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.10.6)
# Requirement already satisfied: six in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (305.1)
# Requirement already satisfied: executing in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\ematt\anaconda3\envs\downgradedpython\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.2)

# %%
from pycaret.classification import *

# %%
import sys
print(sys.version)
# Out:
# 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]

# %%
automl = setup(df, target='Churn')
# Out:
# <style type="text/css">
# #T_83434_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_83434">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83434_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_83434_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83434_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83434_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_83434_row0_col1" class="data row0 col1" >687</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83434_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_83434_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83434_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_83434_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_83434_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_83434_row3_col1" class="data row3 col1" >(7032, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_83434_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_83434_row4_col1" class="data row4 col1" >(7032, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_83434_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_83434_row5_col1" class="data row5 col1" >(4922, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_83434_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_83434_row6_col1" class="data row6 col1" >(2110, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_83434_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_83434_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_83434_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_83434_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_83434_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_83434_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_83434_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_83434_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_83434_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_83434_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_83434_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_83434_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_83434_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_83434_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_83434_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_83434_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_83434_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_83434_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_83434_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_83434_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_83434_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_83434_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_83434_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_83434_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_83434_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_83434_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_83434_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_83434_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_83434_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_83434_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_83434_row21_col1" class="data row21 col1" >17ee</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_ec5cf th {
#   text-align: left;
# }
# #T_ec5cf_row0_col0, #T_ec5cf_row0_col3, #T_ec5cf_row0_col4, #T_ec5cf_row0_col5, #T_ec5cf_row0_col6, #T_ec5cf_row0_col7, #T_ec5cf_row1_col0, #T_ec5cf_row1_col1, #T_ec5cf_row1_col2, #T_ec5cf_row1_col3, #T_ec5cf_row1_col4, #T_ec5cf_row1_col5, #T_ec5cf_row1_col6, #T_ec5cf_row1_col7, #T_ec5cf_row2_col0, #T_ec5cf_row2_col1, #T_ec5cf_row2_col2, #T_ec5cf_row2_col3, #T_ec5cf_row2_col4, #T_ec5cf_row2_col5, #T_ec5cf_row2_col6, #T_ec5cf_row2_col7, #T_ec5cf_row3_col0, #T_ec5cf_row3_col1, #T_ec5cf_row3_col2, #T_ec5cf_row3_col3, #T_ec5cf_row3_col4, #T_ec5cf_row3_col5, #T_ec5cf_row3_col6, #T_ec5cf_row3_col7, #T_ec5cf_row4_col0, #T_ec5cf_row4_col1, #T_ec5cf_row4_col2, #T_ec5cf_row4_col3, #T_ec5cf_row4_col5, #T_ec5cf_row4_col6, #T_ec5cf_row4_col7, #T_ec5cf_row5_col0, #T_ec5cf_row5_col1, #T_ec5cf_row5_col2, #T_ec5cf_row5_col3, #T_ec5cf_row5_col4, #T_ec5cf_row5_col5, #T_ec5cf_row5_col6, #T_ec5cf_row5_col7, #T_ec5cf_row6_col0, #T_ec5cf_row6_col1, #T_ec5cf_row6_col2, #T_ec5cf_row6_col3, #T_ec5cf_row6_col4, #T_ec5cf_row6_col5, #T_ec5cf_row6_col6, #T_ec5cf_row6_col7, #T_ec5cf_row7_col0, #T_ec5cf_row7_col1, #T_ec5cf_row7_col2, #T_ec5cf_row7_col3, #T_ec5cf_row7_col4, #T_ec5cf_row7_col5, #T_ec5cf_row7_col6, #T_ec5cf_row7_col7, #T_ec5cf_row8_col0, #T_ec5cf_row8_col1, #T_ec5cf_row8_col2, #T_ec5cf_row8_col3, #T_ec5cf_row8_col4, #T_ec5cf_row8_col5, #T_ec5cf_row8_col6, #T_ec5cf_row8_col7, #T_ec5cf_row9_col0, #T_ec5cf_row9_col1, #T_ec5cf_row9_col2, #T_ec5cf_row9_col4, #T_ec5cf_row10_col0, #T_ec5cf_row10_col1, #T_ec5cf_row10_col2, #T_ec5cf_row10_col3, #T_ec5cf_row10_col4, #T_ec5cf_row10_col5, #T_ec5cf_row10_col6, #T_ec5cf_row10_col7, #T_ec5cf_row11_col0, #T_ec5cf_row11_col1, #T_ec5cf_row11_col2, #T_ec5cf_row11_col3, #T_ec5cf_row11_col4, #T_ec5cf_row11_col5, #T_ec5cf_row11_col6, #T_ec5cf_row11_col7, #T_ec5cf_row12_col0, #T_ec5cf_row12_col1, #T_ec5cf_row12_col2, #T_ec5cf_row12_col3, #T_ec5cf_row12_col4, #T_ec5cf_row12_col5, #T_ec5cf_row12_col6, #T_ec5cf_row12_col7, #T_ec5cf_row13_col0, #T_ec5cf_row13_col1, #T_ec5cf_row13_col2, #T_ec5cf_row13_col3, #T_ec5cf_row13_col4, #T_ec5cf_row13_col5, #T_ec5cf_row13_col6, #T_ec5cf_row13_col7 {
#   text-align: left;
# }
# #T_ec5cf_row0_col1, #T_ec5cf_row0_col2, #T_ec5cf_row4_col4, #T_ec5cf_row9_col3, #T_ec5cf_row9_col5, #T_ec5cf_row9_col6, #T_ec5cf_row9_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_
row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_ec5cf_row4_col1" class="data row4 col1" >0.7857</td>
#       <td id="T_ec5cf_row4_col2" class="data row4 col2" >0.8241</td>
#       <td id="T_ec5cf_row4_col3" class="data row4 col3" >0.4296</td>
#       <td id="T_ec5cf_row4_col4" class="data row4 col4" >0.6433</td>
#       <td id="T_ec5cf_row4_col5" class="data row4 col5" >0.5132</td>
#       <td id="T_ec5cf_row4_col6" class="data row4 col6" >0.3836</td>
#       <td id="T_ec5cf_row4_col7" class="data row4 col7" >0.3972</td>
#       <td id="T_ec5cf_row4_col8" class="data row4 col8" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_ec5cf_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_ec5cf_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ec5cf_row5_col1" class="data row5 col1" >0.7846</td>
#       <td id="T_ec5cf_row5_col2" class="data row5 col2" >0.8249</td>
#       <td id="T_ec5cf_row5_col3" class="data row5 col3" >0.4992</td>
#       <td id="T_ec5cf_row5_col4" class="data row5 col4" >0.6153</td>
#       <td id="T_ec5cf_row5_col5" class="data row5 col5" >0.5494</td>
#       <td id="T_ec5cf_row5_col6" class="data row5 col6" >0.4106</td>
#       <td id="T_ec5cf_row5_col7" class="data row5 col7" >0.4153</td>

# %%
best_model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=687, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
df.iloc[-2:-1]
# Out:
#             tenure  PhoneService  Contract PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD       4             1         0  Mailed check            74.4
#
#             TotalCharges  Churn  total_tenure_ratio
# customerID
# 8361-LTMKD         306.6      1               76.65

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_7c627">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c627_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7c627_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7c627_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7c627_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7c627_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7c627_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7c627_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7c627_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c627_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c627_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_7c627_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_7c627_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_7c627_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_7c627_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_7c627_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_7c627_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_7c627_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#             tenure  PhoneService  Contract PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD       4             1         0  Mailed check       74.400002
#
#             TotalCharges  total_tenure_ratio  Churn  prediction_label  \
# customerID
# 8361-LTMKD    306.600006           76.650002      1                 0
#
#             prediction_score
# customerID
# 8361-LTMKD            0.5167

# %%
save_model(best_model, 'XGBoost')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['tenure', 'PhoneService',
#                                               'Contract', 'MonthlyCharges',
#                                               'TotalCharges',
#                                               'total_tenure_ratio'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_impu...
#                                                                handle_missing='return_nan',
#                                                                handle_unknown='value',
#                                                                return_df=True,
#                                                                use_cat_names=True,
#                                                                verbose=0))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=687,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'XGBoost.pkl')

# %%
import pickle
with open('XGBoost.pk', 'wb') as f:
    pickle.dump(best_model, f)

# %%
with open('XGBoost.pk', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
loaded_lda = load_model('XGBoost')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_data=df.iloc[-2:-1]

# %%
predict_model(loaded_lda, new_data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b6ffa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6ffa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b6ffa_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b6ffa_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b6ffa_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b6ffa_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b6ffa_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b6ffa_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b6ffa_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6ffa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6ffa_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_b6ffa_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_b6ffa_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_b6ffa_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_b6ffa_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_b6ffa_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_b6ffa_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_b6ffa_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#             tenure  PhoneService  Contract PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD       4             1         0  Mailed check       74.400002
#
#             TotalCharges  total_tenure_ratio  Churn  prediction_label  \
# customerID
# 8361-LTMKD    306.600006           76.650002      1                 0
#
#             prediction_score
# customerID
# 8361-LTMKD            0.5167

# %%
SWITCHED OVER TO VS CODE FOR THE FOLLOWING LINES

# %%
from IPython.display import Code

Code('predict_Churn.py')
# Out:
# predict_Churn.py

# %%
# %run predict_Churn.py

# %% [markdown]
# Write a short summary of the process and results here.

# %% [markdown]
# Using the prepped Churn data from week 2, we utilized AutoML through pycaret. This helps determine the best model with real time fitting.
# The best fit for this data was a logistic regression, however that can change as the data is manipulated. Using this info, I then made predictions
# in a 2D array. The data was saved through pickle. I then attempted to pick the assignmnent up in VS Code to complete the assignmnet but had some
# difficulty.
